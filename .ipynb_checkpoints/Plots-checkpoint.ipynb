# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import glob

# %% [markdown]
# # Caminantes Aleatorios

# %%
#Importamos los datos
X = np.loadtxt('./Data/DataRW.dat')

# %%
#Graficamos un caminante aleatorio
plt.plot(X)
plt.xlabel("t", size = 20)
plt.ylabel('X(t)', size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#Importamos los datos
X = np.loadtxt(r'T00.dat')

# %%
probabilidad = pd.DataFrame(X).groupby(0).mean().index
tiempo_promedio = pd.DataFrame(X).groupby(0).mean()[1]

# %%
#Comparacion de probabilidad con la teoria 
plt.plot(probabilidad, tiempo_promedio, 'ro')
plt.plot(probabilidad, (probabilidad + 0.5)/0.5, 'k-')
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# (array([0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Comparacion de probabilidad con la teoria 
plt.plot(probabilidad, tiempo_promedio, 'ro')
plt.plot(probabilidad, (probabilidad + 0.5)/0.5, 'k-')
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# (array([0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Ahora haremos un histograma de cada p
X = pd.DataFrame(X)

# %%
probs = X[0].unique()

# %%
#Probabilidad para p
tiempo_medio = X[X[0] == 0.01][1].value_counts().index
frecuencia = X[X[0] == 0.01][1].value_counts().values
plt.semilogy(tiempo_medio, frecuencia, '.')

# %%
plt.semilogy(tiempo_medio, frecuencia, '.')

# %% [markdown]
# $$e^{-pt}$$
#
# Asi es como cae

# %%
X
